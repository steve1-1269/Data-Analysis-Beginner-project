# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\MINE\Desktop\data science\Weather data.csv")

# %% [markdown]
# #  Sample of data

# %%
df.sample(5)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 874     2/6/2012 10:00     1.4              -3.3         71               32
# 7726  11/17/2012 22:00    -1.0              -6.3         67                7
# 1597    3/7/2012 13:00     8.9              -4.4         39               13
# 1733    3/13/2012 5:00     5.8               1.1         72                6
# 4769   7/17/2012 17:00    25.9              22.2         80                7
#
#       Visibility_km  Press_kPa       Weather
# 874            24.1     100.60        Cloudy
# 7726           25.0     103.54         Clear
# 1597           24.1     101.49  Mainly Clear
# 1733           25.0     100.71        Cloudy
# 4769           24.1      99.83        Cloudy

# %% [markdown]
# # Data shape
#
# to check the number of rows and columns in a dataset

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# #  DaTA INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# #  Summary of the data

# %%
df.describe(include= 'all')
# Out:
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# ...

# %% [markdown]
# #  Percentage of empty values

# %%
df.isnull().sum()/ len(df) * 100
# Out:
# Date/Time           0.0
# Temp_C              0.0
# Dew Point Temp_C    0.0
# Rel Hum_%           0.0
# Wind Speed_km/h     0.0
# Visibility_km       0.0
# Press_kPa           0.0
# Weather             0.0
# dtype: float64

# %% [markdown]
# #  Data types of data

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# #  Unique values in a column

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# # number of unique values in the data

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# # Columns in data

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# # Count number of values in  each columns of the dataset

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [raw]
#  No null value in the data

# %% [markdown]
# # 1. Find the unique 'wind speed' values in the data

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df['Wind Speed_km/h'].value_counts().reset_index()
# Out:
#     Wind Speed_km/h  count
# 0                 9    830
# 1                11    791
# 2                13    735
# 3                15    719
# 4                 7    677
# 5                17    666
# 6                19    616
# 7                 6    609
# 8                20    496
# 9                 4    474
# 10               22    439
# 11               24    374
# 12                0    309
# 13               26    242
# 14               28    205
# 15               30    161
# 16               32    139
# 17               33     85
# 18               35     53
# 19               37     45
# 20               39     24
# 21               41     22
# 22               44     14
# 23               43     13
# 24               48     13
# 25               46     11
# 26               52      7
# 27               57      5
# 28               50      4
# 29                2      2
# 30               83      1
# 31               70      1
# 32               63      1
# ...

# %% [markdown]
# # 2. Find the number of times where the 'weather is exactly clear'

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df1= df.query('Weather == "Clear" ')

# %%
df1['Weather'].count()
# Out:
# 1326

# %% [markdown]
# # 3.Find the number of time that wind speed was exactly '4km/h'

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df['Wind Speed_km/h'].value_counts()
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %%
df1= df[df['Wind Speed_km/h']== 4]
df1.groupby('Wind Speed_km/h').count()
# Out:
#                  Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Wind Speed_km/h
# 4                      474     474               474        474
#
#                  Visibility_km  Press_kPa  Weather
# Wind Speed_km/h
# 4                          474        474      474

# %% [markdown]
# # 4. Find out all the null values in the data

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # 5. Rename the column weather to wether condition

# %%
df=df.rename(columns= {'Weather': 'Weather_Condition'})
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# #  6. What is the mean 'visibility'

# %%
visibility= df['Visibility_km']

mean_visibility= np.mean(visibility)

# %%
mean_visibility
# Out:
# 27.664446721311478

# %% [markdown]
# #  7. Standard deviation of pressure

# %%
pressure= df['Press_kPa']

sd_pressure= np.std(pressure)

# %%
sd_pressure
# Out:
# 0.8439567024167486

# %% [markdown]
# # 8. What is the variance of relative humidity of the data

# %%
humidity= df['Rel Hum_%']

var= np.var(humidity)

# %%
var
# Out:
# 286.2159627041693

# %% [markdown]
# #  9. find all instances where snow was recorded

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
df['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
snow= df[df['Weather_Condition'].str.contains('Snow')]
snow.groupby('Weather_Condition').count().reset_index()
# Out:
#              Weather_Condition  Date/Time  Temp_C  Dew Point Temp_C  \
# 0                 Drizzle,Snow          2       2                 2
# 1             Drizzle,Snow,Fog         15      15                15
# 2        Freezing Drizzle,Snow         11      11                11
# 3    Freezing Rain,Snow Grains          1       1                 1
# 4                Moderate Snow          4       4                 4
# 5   Moderate Snow,Blowing Snow          2       2                 2
# 6    Rain Showers,Snow Showers          2       2                 2
# 7                    Rain,Snow         18      18                18
# 8             Rain,Snow Grains          1       1                 1
# 9                Rain,Snow,Fog          1       1                 1
# 10       Rain,Snow,Ice Pellets          4       4                 4
# 11                        Snow        390     390               390
# 12                Snow Pellets          1       1                 1
# ...

# %%
snow['Weather_Condition'].count()
# Out:
# 583

# %% [markdown]
# #  10. find all the instances where 'wind speed is above 24' and 'visibility is 25'

# %%
instances= df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km']== 25)]

# %%
instances.sample(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 7246  10/28/2012 22:00    11.0               7.4         78               32
# 6046    9/8/2012 22:00    14.2              10.8         80               30
# 2708   4/22/2012 20:00     5.3              -0.6         66               32
# 5829   8/30/2012 21:00    24.5              15.6         58               44
# 170      1/8/2012 2:00    -1.7              -6.2         71               30
# 2756   4/24/2012 20:00     6.9               0.0         61               28
# 6835  10/11/2012 19:00     8.4               2.2         65               37
# 6931  10/15/2012 19:00    12.9               8.3         74               30
# 8252   12/9/2012 20:00    -2.2              -7.2         69               28
# 270     1/12/2012 6:00    -7.6             -13.1         65               28
#
#       Visibility_km  Press_kPa Weather_Condition
# 7246           25.0     101.01     Mostly Cloudy
# ...

# %%
instances.count()
# Out:
# Date/Time            308
# Temp_C               308
# Dew Point Temp_C     308
# Rel Hum_%            308
# Wind Speed_km/h      308
# Visibility_km        308
# Press_kPa            308
# Weather_Condition    308
# dtype: int64

# %% [markdown]
# #  11. What is the mean value of each columns against weather condition

# %%
# df.groupby('Weather_Condition').mean()

# %% [markdown]
# #  12. What is the minimum value of each columns against weather condition

# %%
# minimum value

df.groupby('Weather_Condition').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
# maximum value

df.groupby('Weather_Condition').max().reset_index()
# Out:
#                           Weather_Condition         Date/Time  Temp_C  \
# 0                                     Clear     9/9/2012 5:00    32.8
# 1                                    Cloudy    9/9/2012 23:00    30.5
# 2                                   Drizzle    9/30/2012 3:00    18.8
# 3                               Drizzle,Fog    9/30/2012 2:00    19.9
# 4                   Drizzle,Ice Pellets,Fog   12/17/2012 9:00     0.4
# 5                              Drizzle,Snow  12/19/2012 18:00     1.2
# 6                          Drizzle,Snow,Fog   12/22/2012 3:00     1.1
# 7                                       Fog    9/22/2012 0:00    20.8
# 8                          Freezing Drizzle     2/1/2012 5:00    -2.3
# 9                      Freezing Drizzle,Fog   12/10/2012 5:00    -0.3
# 10                    Freezing Drizzle,Haze    2/1/2012 13:00    -5.0
# 11                    Freezing Drizzle,Snow    3/2/2012 12:00    -3.3
# ...

# %% [markdown]
# # 13. Show all the records where weather condition is fog

# %%
fog= df[df['Weather_Condition'].str.contains('Fog')]
# fog= df[df['Weather_Condition'] == 'Fog']

# %%
fog
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %% [markdown]
# # 14. Find all instances when 'weather is clear' or visibility above 40

# %%
df[(df['Weather_Condition']== 'Clear') | (df['Visibility_km']> 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# # Find all instances when
# # 'weather is clear' and 'relative humidity is greather than 50'  Or
#
# # 'visibility is above 50'

# %%
df[(df['Weather_Condition']== 'Clear') & (df['Rel Hum_%']>50) | (df['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
